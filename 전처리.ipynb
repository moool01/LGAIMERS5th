# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# ### 엑셀 파일 csv 전환 함수

# %%
def read_excel_file(file_path: str, header: int = None) -> pd.DataFrame:
    csv_file = file_path.replace(".xlsx", ".csv")

    if not os.path.exists(csv_file):
        print("Converting excel to csv...")
        if header:
            df = pd.read_excel(file_path, header=header)
        else:
            df = pd.read_excel(file_path)

        df.to_csv(csv_file, index=False)
        print(f"  {file_path} -> {csv_file}")
        return df
    else:
        print(f"  Reading {csv_file}")
        return pd.read_csv(csv_file, low_memory=False)

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

X_Dam = read_excel_file(os.path.join(ROOT_DIR, "Dam dispensing.xlsx"), header=0)  # 1: 헤더 없음, 0: N값 없음

X_AutoClave = read_excel_file(
    os.path.join(ROOT_DIR, "Auto clave.xlsx"), header=0
)

X_Fill1 = read_excel_file(
    os.path.join(ROOT_DIR, "Fill1 dispensing.xlsx"), header=0
)

X_Fill2 = read_excel_file(
    os.path.join(ROOT_DIR, "Fill2 dispensing.xlsx"), header=0
)

y = pd.read_csv(os.path.join(ROOT_DIR, "train_y.csv"))

# %% [markdown]
# ### Dam dispensing

# %%
dam = pd.read_csv("C:\박소현\LG 해커톤\data\Dam dispensing(헤더,N).csv", encoding='cp949', low_memory=False, header = 1)
dam.shape
# Out:
# (62479, 222)

# %%
# 각 열의 결측치 수 확인
missing_dam = dam.isnull().sum()

# 결측치가 600000개 이상인 열만 필터링
missing_columns_dam = missing_dam[missing_dam > 60000].index
print(missing_columns_dam.size)
missing_columns_dam
# Out:
# 140
# Index(['Box ID', 'Unit Time', 'Judge Value', 'Unit Time.1', 'Judge Value.1',
#        'Unit Time.2', 'Judge Value.2', 'Unit Time.3', 'Judge Value.3',
#        'Unit Time.4',
#        ...
#        'Unit Time.65', 'Judge Value.65', 'Unit Time.66', 'Judge Value.66',
#        'Unit Time.67', 'Judge Value.67', 'Unit Time.68', 'Judge Value.68',
#        'Unit Time.69', 'Judge Value.69'],
#       dtype='object', length=140)

# %%
# 결측치가 60,000개 이상인 열 제거
dam = dam.drop(columns=missing_columns_dam)
dam
# Out:
#       Wip Line  Process Desc.         Equipment Model.Suffix   Workorder  \
# 0      IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334501  3F1X5847-2
# 1      IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334501  3F1X5847-2
# 2      IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334501  3F1X5847-2
# 3      IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334501  3F1X5847-2
# 4      IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334501  3F1X5847-2
# ...        ...            ...               ...          ...         ...
# 62474  IVI-OB6  Dam Dispenser  Dam dispenser #2  AJX75334505  4F1XB738-1
# 62475  IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334505  4F1XB738-1
# 62476  IVI-OB6  Dam Dispenser  Dam dispenser #2  AJX75334505  4F1XB738-1
# 62477  IVI-OB6  Dam Dispenser  Dam dispenser #1  AJX75334505  4F1XB738-1
# 62478  IVI-OB6  Dam Dispenser  Dam dispenser #2  AJX75334505  4F1XB738-1
#
#                      LOT ID                Set ID      Collect Date  \
# 0      OP753345013050000002  OP753345013050000002   2023-05-04 8:57
# 1      OP753345013050000003  OP753345013050000003   2023-05-04 9:11
# 2      OP753345013050000004  OP753345013050000004   2023-05-04 9:13
# 3      OP753345013050000005  OP753345013050000005   2023-05-04 9:15
# 4      OP753345013050000006  OP753345013050000006   2023-05-04 9:17
# ...                     ...                   ...               ...
# 62474  OP753345054040002685  OP753345054040002685  2024-04-28 18:30
# 62475  OP753345054040002686  OP753345054040002686  2024-04-28 18:31
# 62476  OP753345054040002687  OP753345054040002687  2024-04-28 18:32
# 62477  OP753345054040002688  OP753345054040002688  2024-04-28 18:33
# 62478  OP753345054040002689  OP753345054040002689  2024-04-28 18:34
#
#        Insp. Seq No. Insp Judge Code  ...  Collect Result.61  \
# 0                  1              OK  ...               9000
# 1                  1              OK  ...               9000
# 2                  1              OK  ...               9000
# 3                  1              OK  ...               9000
# 4                  1              OK  ...               9000
# ...              ...             ...  ...                ...
# 62474              1              OK  ...               5800
# 62475              1              OK  ...               5800
# 62476              1              OK  ...               5800
# 62477              1              OK  ...               5800
# 62478              1              OK  ...               5800
#
#        Collect Result.62  Collect Result.63  Collect Result.64  \
# 0                   7000               9000               7000
# 1                   7000               9000               7000
# 2                   7000               9000               7000
# 3                   7000               9000               7000
# 4                   7000               9000               7000
# ...                  ...                ...                ...
# 62474               5800               5800               5800
# 62475               5800               5800               5800
# 62476               5800               5800               5800
# 62477               5800               5800               5800
# 62478               5800               5800               5800
#
#        Collect Result.65  Collect Result.66  Collect Result.67  \
# 0                   9000                  0                0.0
# 1                   9000                  0                0.0
# 2                   9000                  0                0.0
# 3                   9000                  0                0.0
# 4                   9000                  0                0.0
# ...                  ...                ...                ...
# 62474               5800               5800                0.0
# 62475               5800               5800                0.0
# 62476               5800               5800                0.0
# 62477               5800               5800                0.0
# 62478               5800               5800                0.0
#
#        Collect Result.68  Collect Result.69  Unnamed: 221
# 0                    0.0                7.0           NaN
# 1                    0.0                7.0           NaN
# 2                    0.0                7.0           NaN
# 3                    0.0                7.0           NaN
# 4                    0.0                7.0           NaN
# ...                  ...                ...           ...
# 62474                0.0                0.0           7.0
# 62475                0.0                0.0           7.0
# 62476                0.0                0.0           7.0
# 62477                0.0                0.0           7.0
# 62478                0.0                0.0           7.0
#
# [62479 rows x 82 columns]

# %%
# 각 열의 결측치 수 확인
missing_dam = dam.isnull().sum()

# 결측치가 있는 열 확인
missing_dam[missing_dam > 0]
# Out:
# Collect Result.17    19445
# Judge Value.17       45329
# Unnamed: 221         25884
# dtype: int64

# %% [markdown]
# ### Fill1 dispensing

# %%
fill1 = pd.read_csv("C:\박소현\LG 해커톤\data\Fill1 dispensing(헤더,N).csv", encoding='cp949', low_memory=False, header = 1)
fill1.shape
# Out:
# (61928, 102)

# %%
# 각 열의 결측치 수 확인
missing_fill1 = fill1.isnull().sum()

# 결측치가 600000개 이상인 열만 필터링
missing_columns_fill1 = missing_fill1[missing_fill1 > 60000].index
print(missing_columns_fill1.size)
missing_columns_fill1
# Out:
# 60
# Index(['Box ID', 'Unit Time', 'Judge Value', 'Unit Time.1', 'Judge Value.1',
#        'Unit Time.2', 'Judge Value.2', 'Unit Time.3', 'Judge Value.3',
#        'Unit Time.4', 'Judge Value.4', 'Unit Time.5', 'Judge Value.5',
#        'Unit Time.6', 'Judge Value.6', 'Unit Time.7', 'Unit Time.8',
#        'Judge Value.8', 'Unit Time.9', 'Judge Value.9', 'Unit Time.10',
#        'Judge Value.10', 'Unit Time.11', 'Judge Value.11', 'Unit Time.12',
#        'Judge Value.12', 'Unit Time.13', 'Judge Value.13', 'Unit Time.14',
#        'Judge Value.14', 'Unit Time.15', 'Judge Value.15', 'Unit Time.16',
#        'Judge Value.16', 'Unit Time.17', 'Judge Value.17', 'Unit Time.18',
#        'Judge Value.18', 'Unit Time.19', 'Judge Value.19', 'Unit Time.20',
#        'Judge Value.20', 'Unit Time.21', 'Judge Value.21', 'Unit Time.22',
#        'Judge Value.22', 'Unit Time.23', 'Judge Value.23', 'Unit Time.24',
#        'Judge Value.24', 'Unit Time.25', 'Judge Value.25', 'Unit Time.26',
#        'Judge Value.26', 'Unit Time.27', 'Judge Value.27', 'Unit Time.28',
#        'Judge Value.28', 'Unit Time.29', 'Judge Value.29'],
#       dtype='object')

# %%
# 결측치가 60,000개 이상인 열 제거
fill1 = fill1.drop(columns=missing_columns_fill1)
fill1
# Out:
#       Wip Line    Process Desc.           Equipment Model.Suffix   Workorder  \
# 0      IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334501  3F1X5847-2
# 1      IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334501  3F1X5847-2
# 2      IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334501  3F1X5847-2
# 3      IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334501  3F1X5847-2
# 4      IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334501  3F1X5847-2
# ...        ...              ...                 ...          ...         ...
# 61923  IVI-OB6  Fill1 Dispenser  Fill1 dispenser #2  AJX75334505  4F1XB738-1
# 61924  IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334505  4F1XB738-1
# 61925  IVI-OB6  Fill1 Dispenser  Fill1 dispenser #2  AJX75334505  4F1XB738-1
# 61926  IVI-OB6  Fill1 Dispenser  Fill1 dispenser #1  AJX75334505  4F1XB738-1
# 61927  IVI-OB6  Fill1 Dispenser  Fill1 dispenser #2  AJX75334505  4F1XB738-1
#
#                      LOT ID                Set ID      Collect Date  \
# 0      OP753345013050000002  OP753345013050000002   2023-05-04 8:59
# 1      OP753345013050000003  OP753345013050000003   2023-05-04 9:13
# 2      OP753345013050000004  OP753345013050000004   2023-05-04 9:15
# 3      OP753345013050000005  OP753345013050000005   2023-05-04 9:17
# 4      OP753345013050000006  OP753345013050000006   2023-05-04 9:19
# ...                     ...                   ...               ...
# 61923  OP753345054040002685  OP753345054040002685  2024-04-28 18:32
# 61924  OP753345054040002686  OP753345054040002686  2024-04-28 18:33
# 61925  OP753345054040002687  OP753345054040002687  2024-04-28 18:34
# 61926  OP753345054040002688  OP753345054040002688  2024-04-28 18:35
# 61927  OP753345054040002689  OP753345054040002689  2024-04-28 18:36
#
#        Insp. Seq No. Insp Judge Code  ...  Collect Result.21  \
# 0                  1              OK  ...               92.2
# 1                  1              OK  ...               92.2
# 2                  1              OK  ...               92.2
# 3                  1              OK  ...               92.2
# 4                  1              OK  ...               92.2
# ...              ...             ...  ...                ...
# 61923              1              OK  ...               50.0
# 61924              1              OK  ...               50.0
# 61925              1              OK  ...               50.0
# 61926              1              OK  ...               50.0
# 61927              1              OK  ...               50.0
#
#        Collect Result.22  Collect Result.23  Collect Result.24  \
# 0                  289.0                 50                 85
# 1                  289.0                 50                 85
# 2                  289.0                 50                 85
# 3                  289.0                 50                 85
# 4                  289.0                 50                 85
# ...                  ...                ...                ...
# 61923               92.2                289                 50
# 61924               92.2                289                 50
# 61925               92.2                289                 50
# 61926               92.2                289                 50
# 61927               92.2                289                 50
#
#        Collect Result.25  Collect Result.26  Collect Result.27  \
# 0                  111.0                7.0                  1
# 1                  110.9                5.0                  2
# 2                  111.0                6.0                  3
# 3                  110.9                7.0                  4
# 4                  111.0                8.0                  5
# ...                  ...                ...                ...
# 61923              128.0               57.5                 11
# 61924              128.0               57.4                  5
# 61925              128.0               57.7                 12
# 61926              128.0               52.8                  6
# 61927              128.0               54.7                 13
#
#       Collect Result.28 Collect Result.29  Unnamed: 101
# 0                     1                 7           NaN
# 1                     1                 7           NaN
# 2                     1                 7           NaN
# 3                     1                 7           NaN
# 4                     1                 7           NaN
# ...                 ...               ...           ...
# 61923               435                 1           7.0
# 61924               436                 1           7.0
# 61925               437                 1           7.0
# 61926               438                 1           7.0
# 61927               439                 1           7.0
#
# [61928 rows x 42 columns]

# %%
# 각 열의 결측치 수 확인
missing_fill1 = fill1.isnull().sum()

# 결측치가 있는 열 확인
missing_fill1[missing_fill1 > 0]
# Out:
# Collect Result.7    19126
# Judge Value.7       44962
# Unnamed: 101        50663
# dtype: int64

# %% [markdown]
# ### FIll2 dispensing

# %%
fill2 = pd.read_csv("C:\박소현\LG 해커톤\data\Fill2 dispensing(헤더,N).csv", encoding='cp949', low_memory=False, header = 1)
fill2.shape
# Out:
# (62318, 132)

# %%
# 각 열의 결측치 수 확인
missing_fill2 = fill2.isnull().sum()

# 결측치가 600000개 이상인 열만 필터링
missing_columns_fill2 = missing_fill2[missing_fill2 > 60000].index
print(missing_columns_fill2.size)
missing_columns_fill2
# Out:
# 80
# Index(['Box ID', 'Unit Time', 'Judge Value', 'Unit Time.1', 'Judge Value.1',
#        'Unit Time.2', 'Judge Value.2', 'Unit Time.3', 'Judge Value.3',
#        'Unit Time.4', 'Judge Value.4', 'Unit Time.5', 'Judge Value.5',
#        'Unit Time.6', 'Judge Value.6', 'Unit Time.7', 'Judge Value.7',
#        'Unit Time.8', 'Judge Value.8', 'Unit Time.9', 'Judge Value.9',
#        'Unit Time.10', 'Judge Value.10', 'Unit Time.11', 'Judge Value.11',
#        'Unit Time.12', 'Judge Value.12', 'Unit Time.13', 'Judge Value.13',
#        'Unit Time.14', 'Judge Value.14', 'Unit Time.15', 'Judge Value.15',
#        'Unit Time.16', 'Judge Value.16', 'Unit Time.17', 'Unit Time.18',
#        'Judge Value.18', 'Unit Time.19', 'Judge Value.19', 'Unit Time.20',
#        'Judge Value.20', 'Unit Time.21', 'Judge Value.21', 'Unit Time.22',
#        'Judge Value.22', 'Unit Time.23', 'Judge Value.23', 'Unit Time.24',
#        'Judge Value.24', 'Unit Time.25', 'Judge Value.25', 'Unit Time.26',
#        'Judge Value.26', 'Unit Time.27', 'Judge Value.27', 'Unit Time.28',
#        'Judge Value.28', 'Unit Time.29', 'Judge Value.29', 'Unit Time.30',
#        'Judge Value.30', 'Unit Time.31', 'Judge Value.31', 'Unit Time.32',
#        'Judge Value.32', 'Unit Time.33', 'Judge Value.33', 'Unit Time.34',
#        'Judge Value.34', 'Unit Time.35', 'Judge Value.35', 'Unit Time.36',
#        'Judge Value.36', 'Unit Time.37', 'Judge Value.37', 'Unit Time.38',
#        'Judge Value.38', 'Unit Time.39', 'Judge Value.39'],
#       dtype='object')

# %%
# 결측치가 60,000개 이상인 열 제거
fill2 = fill2.drop(columns=missing_columns_fill2)
fill2
# Out:
#       Wip Line    Process Desc.           Equipment Model.Suffix   Workorder  \
# 0      IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334501  3F1X5847-2
# 1      IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334501  3F1X5847-2
# 2      IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334501  3F1X5847-2
# 3      IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334501  3F1X5847-2
# 4      IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334501  3F1X5847-2
# ...        ...              ...                 ...          ...         ...
# 62313  IVI-OB6  Fill2 Dispenser  Fill2 dispenser #2  AJX75334505  4F1XB738-1
# 62314  IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334505  4F1XB738-1
# 62315  IVI-OB6  Fill2 Dispenser  Fill2 dispenser #2  AJX75334505  4F1XB738-1
# 62316  IVI-OB6  Fill2 Dispenser  Fill2 dispenser #1  AJX75334505  4F1XB738-1
# 62317  IVI-OB6  Fill2 Dispenser  Fill2 dispenser #2  AJX75334505  4F1XB738-1
#
#                      LOT ID                Set ID      Collect Date  \
# 0      OP753345013050000002  OP753345013050000002   2023-05-04 9:00
# 1      OP753345013050000003  OP753345013050000003   2023-05-04 9:15
# 2      OP753345013050000004  OP753345013050000004   2023-05-04 9:17
# 3      OP753345013050000005  OP753345013050000005   2023-05-04 9:19
# 4      OP753345013050000006  OP753345013050000006   2023-05-04 9:21
# ...                     ...                   ...               ...
# 62313  OP753345054040002685  OP753345054040002685  2024-04-28 18:33
# 62314  OP753345054040002686  OP753345054040002686  2024-04-28 18:34
# 62315  OP753345054040002687  OP753345054040002687  2024-04-28 18:35
# 62316  OP753345054040002688  OP753345054040002688  2024-04-28 18:36
# 62317  OP753345054040002689  OP753345054040002689  2024-04-28 18:37
#
#        Insp. Seq No. Insp Judge Code  ...  Collect Result.31  \
# 0                  1              OK  ...               91.8
# 1                  1              OK  ...               91.8
# 2                  1              OK  ...               91.8
# 3                  1              OK  ...               91.8
# 4                  1              OK  ...               91.8
# ...              ...             ...  ...                ...
# 62313              1              OK  ...               50.0
# 62314              1              OK  ...               50.0
# 62315              1              OK  ...               50.0
# 62316              1              OK  ...               50.0
# 62317              1              OK  ...               50.0
#
#        Collect Result.32  Collect Result.33  Collect Result.34  \
# 0                  270.0                 50                 85
# 1                  270.0                 50                 85
# 2                  270.0                 50                 85
# 3                  270.0                 50                 85
# 4                  270.0                 50                 85
# ...                  ...                ...                ...
# 62313               91.8                270                 50
# 62314               91.8                270                 50
# 62315               91.8                270                 50
# 62316               91.8                270                 50
# 62317               91.8                270                 50
#
#        Collect Result.35  Collect Result.36  Collect Result.37  \
# 0                 17.800                7.0                  1
# 1                 18.200                5.0                  2
# 2                 18.400                6.0                  3
# 3                 18.600                7.0                  4
# 4                 18.100                8.0                  5
# ...                  ...                ...                ...
# 62313            114.612               19.4                 11
# 62314            114.612               19.4                  5
# 62315            114.612               19.0                 12
# 62316            114.612               18.8                  6
# 62317            114.612               18.8                 13
#
#        Collect Result.38  Collect Result.39  Unnamed: 131
# 0                      1                  0           NaN
# 1                      1                  0           NaN
# 2                      1                  0           NaN
# 3                      1                  0           NaN
# 4                      1                  0           NaN
# ...                  ...                ...           ...
# 62313                435                  1           0.0
# 62314                436                  1           0.0
# 62315                437                  1           0.0
# 62316                438                  1           0.0
# 62317                439                  1           0.0
#
# [62318 rows x 52 columns]

# %%
# 각 열의 결측치 수 확인
missing_fill2 = fill2.isnull().sum()

# 결측치가 있는 열 확인
missing_fill2[missing_fill2 > 0]
# Out:
# Collect Result.17    19393
# Judge Value.17       45198
# Unnamed: 131         25805
# dtype: int64

# %% [markdown]
# ### Auto clave

# %%
auto = pd.read_csv("C:\박소현\LG 해커톤\data\Auto clave(헤더,N).csv", encoding='cp949', low_memory=False, header = 1)
auto.shape
# Out:
# (61052, 26)

# %%
# 각 열의 결측치 수 확인
missing_auto = auto.isnull().sum()

# 결측치가 600000개 이상인 열만 필터링
missing_columns_auto = missing_auto[missing_auto > 60000].index
print(missing_columns_auto.size)
missing_columns_auto
# Out:
# 2
# Index(['Box ID', 'Unit Time.4'], dtype='object')

# %%
# 결측치가 60,000개 이상인 열 제거
auto = auto.drop(columns=missing_columns_auto)
auto
# Out:
#       Wip Line   Process Desc.       Equipment Model.Suffix   Workorder  \
# 0      IVI-OB6  Auto Clave Out  Auto Clave Out  AJX75334501  3F1X5847-2
# 1      IVI-OB6  Auto Clave Out  Auto Clave Out  AJX75334501  3F1X5847-2
# 2      IVI-OB6  Auto Clave Out  Auto Clave Out  AJX75334501  3F1X5847-2
# 3      IVI-OB6  Auto Clave Out  Auto Clave Out  AJX75334501  3F1X5847-2
# 4      IVI-OB6  Auto Clave Out  Auto Clave Out  AJX75334501  3F1X5847-2
# ...        ...             ...             ...          ...         ...
# 61047  IVI-OB6  Auto Clave Out  Auto Clave Out  EAT65200901  4EPM0222-2
# 61048  IVI-OB6  Auto Clave Out  Auto Clave Out  EAT65200901  4EPM0222-2
# 61049  IVI-OB6  Auto Clave Out  Auto Clave Out  EAT65200901  4EPM0222-2
# 61050  IVI-OB6  Auto Clave Out  Auto Clave Out  EAT65200901  4EPM0222-2
# 61051  IVI-OB6  Auto Clave Out  Auto Clave Out  EAT65200901  4EPM0222-2
#
#                      LOT ID                Set ID      Collect Date  \
# 0      OP753345013050000002  OP753345013050000002   2023-05-04 9:29
# 1      OP753345013050000003  OP753345013050000003   2023-05-04 9:49
# 2      OP753345013050000004  OP753345013050000004   2023-05-04 9:49
# 3      OP753345013050000005  OP753345013050000005   2023-05-04 9:49
# 4      OP753345013050000006  OP753345013050000006   2023-05-04 9:49
# ...                     ...                   ...               ...
# 61047  OP652009014040000066  OP652009014040000066  2024-04-20 12:03
# 61048  OP652009014040000067  OP652009014040000067  2024-04-20 12:03
# 61049  OP652009014040000068  OP652009014040000068  2024-04-20 11:52
# 61050  OP652009014040000069  OP652009014040000069  2024-04-20 11:52
# 61051  OP652009014040000070  OP652009014040000070  2024-04-20 11:42
#
#        Insp. Seq No. Insp Judge Code  ...  Unit Time.1  Judge Value.1  \
# 0                  1              OK  ...          120             OK
# 1                  1              OK  ...          120             OK
# 2                  1              OK  ...          120             OK
# 3                  1              OK  ...          120             OK
# 4                  1              OK  ...          120             OK
# ...              ...             ...  ...          ...            ...
# 61047              1              OK  ...          120             OK
# 61048              1              OK  ...          120             OK
# 61049              1              OK  ...          120             OK
# 61050              1              OK  ...          120             OK
# 61051              1              OK  ...          120             OK
#
#       Collect Result.2  Unit Time.2  Judge Value.2 Collect Result.3  \
# 0                0.503           90             OK               56
# 1                0.501           90             OK               50
# 2                0.501           90             OK               50
# 3                0.501           90             OK               50
# 4                0.501           90             OK               50
# ...                ...          ...            ...              ...
# 61047            0.499          120             OK               35
# 61048            0.499          120             OK               35
# 61049            0.500          120             OK               36
# 61050            0.500          120             OK               36
# 61051            0.498          120             OK               36
#
#        Unit Time.3  Judge Value.3 Collect Result.4  Judge Value.4
# 0              510             OK              NaN            NaN
# 1              510             OK              NaN            NaN
# 2              510             OK              NaN            NaN
# 3              510             OK              NaN            NaN
# 4              510             OK              NaN            NaN
# ...            ...            ...              ...            ...
# 61047          360             OK              NaN            NaN
# 61048          360             OK              NaN            NaN
# 61049          360             OK              NaN            NaN
# 61050          360             OK              NaN            NaN
# 61051          360             OK              NaN            NaN
#
# [61052 rows x 24 columns]

# %%
# 각 열의 결측치 수 확인
missing_auto = auto.isnull().sum()

# 결측치가 있는 열 확인
missing_auto[missing_auto > 0]
# Out:
# Collect Result.4    44110
# Judge Value.4       44110
# dtype: int64

# %% [markdown]
# ### 데이터 병합

# %%
# Rename columns
dam.columns = [i + " - Dam" for i in dam.columns]
fill1.columns = [i + " - Fill1" for i in fill1.columns]
fill2.columns = [i + " - Fill2" for i in fill2.columns]
auto.columns = [i + " - AutoClave" for i in auto.columns]
dam = dam.rename(columns={"Set ID - Dam": "Set ID"})
fill1 = fill1.rename(columns={"Set ID - Fill1": "Set ID"})
fill2 = fill2.rename(columns={"Set ID - Fill2": "Set ID"})
auto = auto.rename(columns={"Set ID - AutoClave": "Set ID"})

# %%
# Merge X
X = pd.merge(dam, fill1, on="Set ID")
X = pd.merge(X, fill2, on="Set ID")
X = pd.merge(X, auto, on="Set ID")
X = X.drop_duplicates(subset="Set ID").reset_index(drop=True)
X
# Out:
#       Wip Line - Dam Process Desc. - Dam   Equipment - Dam Model.Suffix - Dam  \
# 0            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 1            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 2            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 3            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 4            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# ...              ...                 ...               ...                ...
# 57862        IVI-OB6       Dam Dispenser  Dam dispenser #2        AJX75334505
# 57863        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 57864        IVI-OB6       Dam Dispenser  Dam dispenser #2        AJX75334505
# 57865        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 57866        IVI-OB6       Dam Dispenser  Dam dispenser #2        AJX75334505
#
#       Workorder - Dam          LOT ID - Dam                Set ID  \
# 0          3F1X5847-2  OP753345013050000002  OP753345013050000002
# 1          3F1X5847-2  OP753345013050000003  OP753345013050000003
# 2          3F1X5847-2  OP753345013050000004  OP753345013050000004
# 3          3F1X5847-2  OP753345013050000005  OP753345013050000005
# 4          3F1X5847-2  OP753345013050000006  OP753345013050000006
# ...               ...                   ...                   ...
# 57862      4F1XB738-1  OP753345054040002685  OP753345054040002685
# 57863      4F1XB738-1  OP753345054040002686  OP753345054040002686
# 57864      4F1XB738-1  OP753345054040002687  OP753345054040002687
# 57865      4F1XB738-1  OP753345054040002688  OP753345054040002688
# 57866      4F1XB738-1  OP753345054040002689  OP753345054040002689
#
#       Collect Date - Dam  Insp. Seq No. - Dam Insp Judge Code - Dam  ...  \
# 0        2023-05-04 8:57                    1                    OK  ...
# 1        2023-05-04 9:11                    1                    OK  ...
# 2        2023-05-04 9:13                    1                    OK  ...
# 3        2023-05-04 9:15                    1                    OK  ...
# 4        2023-05-04 9:17                    1                    OK  ...
# ...                  ...                  ...                   ...  ...
# 57862   2024-04-28 18:30                    1                    OK  ...
# 57863   2024-04-28 18:31                    1                    OK  ...
# 57864   2024-04-28 18:32                    1                    OK  ...
# 57865   2024-04-28 18:33                    1                    OK  ...
# 57866   2024-04-28 18:34                    1                    OK  ...
#
#        Unit Time.1 - AutoClave  Judge Value.1 - AutoClave  \
# 0                          120                         OK
# 1                          120                         OK
# 2                          120                         OK
# 3                          120                         OK
# 4                          120                         OK
# ...                        ...                        ...
# 57862                        1                         OK
# 57863                        1                         OK
# 57864                        1                         OK
# 57865                        1                         OK
# 57866                        1                         OK
#
#        Collect Result.2 - AutoClave  Unit Time.2 - AutoClave  \
# 0                             0.503                       90
# 1                             0.501                       90
# 2                             0.501                       90
# 3                             0.501                       90
# 4                             0.501                       90
# ...                             ...                      ...
# 57862                         0.499                      120
# 57863                         0.499                      120
# 57864                         0.499                      120
# 57865                         0.499                      120
# 57866                         0.499                      120
#
#        Judge Value.2 - AutoClave  Collect Result.3 - AutoClave  \
# 0                             OK                            56
# 1                             OK                            50
# 2                             OK                            50
# 3                             OK                            50
# 4                             OK                            50
# ...                          ...                           ...
# 57862                         OK                            55
# 57863                         OK                            55
# 57864                         OK                            55
# 57865                         OK                            55
# 57866                         OK                            55
#
#        Unit Time.3 - AutoClave  Judge Value.3 - AutoClave  \
# 0                          510                         OK
# 1                          510                         OK
# 2                          510                         OK
# 3                          510                         OK
# 4                          510                         OK
# ...                        ...                        ...
# 57862                      361                         OK
# 57863                      361                         OK
# 57864                      361                         OK
# 57865                      361                         OK
# 57866                      361                         OK
#
#        Collect Result.4 - AutoClave  Judge Value.4 - AutoClave
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 57862                           NaN                        NaN
# 57863                           NaN                        NaN
# 57864                           NaN                        NaN
# 57865                           NaN                        NaN
# 57866                           NaN                        NaN
#
# [57867 rows x 197 columns]

# %%
X.to_csv("X.csv", index=False)

# %%
y = pd.read_csv("C:\\박소현\\LG 해커톤\\data\\train_y.csv")

# %%
# Merge X and y
df_merged = pd.merge(X, y, "inner", on="Set ID")
df_merged
# Out:
#       Wip Line - Dam Process Desc. - Dam   Equipment - Dam Model.Suffix - Dam  \
# 0            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 1            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 2            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 3            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 4            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# ...              ...                 ...               ...                ...
# 40501        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40502        IVI-OB6       Dam Dispenser  Dam dispenser #2        AJX75334505
# 40503        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40504        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40505        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
#
#       Workorder - Dam          LOT ID - Dam                Set ID  \
# 0          3F1X5847-2  OP753345013050000003  OP753345013050000003
# 1          3F1X5847-2  OP753345013050000004  OP753345013050000004
# 2          3F1X5847-2  OP753345013050000007  OP753345013050000007
# 3          3F1X5847-2  OP753345013050000011  OP753345013050000011
# 4          3F1X5847-2  OP753345013050000024  OP753345013050000024
# ...               ...                   ...                   ...
# 40501      4F1XB738-1  OP753345054040002680  OP753345054040002680
# 40502      4F1XB738-1  OP753345054040002681  OP753345054040002681
# 40503      4F1XB738-1  OP753345054040002682  OP753345054040002682
# 40504      4F1XB738-1  OP753345054040002684  OP753345054040002684
# 40505      4F1XB738-1  OP753345054040002688  OP753345054040002688
#
#       Collect Date - Dam  Insp. Seq No. - Dam Insp Judge Code - Dam  ...  \
# 0        2023-05-04 9:11                    1                    OK  ...
# 1        2023-05-04 9:13                    1                    OK  ...
# 2        2023-05-04 9:19                    1                    OK  ...
# 3       2023-05-04 11:19                    1                    OK  ...
# 4        2023-05-05 9:35                    1                    OK  ...
# ...                  ...                  ...                   ...  ...
# 40501   2024-04-28 18:25                    1                    OK  ...
# 40502   2024-04-28 18:26                    1                    OK  ...
# 40503   2024-04-28 18:27                    1                    OK  ...
# 40504   2024-04-28 18:29                    1                    OK  ...
# 40505   2024-04-28 18:33                    1                    OK  ...
#
#        Judge Value.1 - AutoClave  Collect Result.2 - AutoClave  \
# 0                             OK                         0.501
# 1                             OK                         0.501
# 2                             OK                         0.502
# 3                             OK                         0.500
# 4                             OK                         0.501
# ...                          ...                           ...
# 40501                         OK                         0.499
# 40502                         OK                         0.499
# 40503                         OK                         0.499
# 40504                         OK                         0.499
# 40505                         OK                         0.499
#
#        Unit Time.2 - AutoClave  Judge Value.2 - AutoClave  \
# 0                           90                         OK
# 1                           90                         OK
# 2                           90                         OK
# 3                           90                         OK
# 4                           90                         OK
# ...                        ...                        ...
# 40501                      120                         OK
# 40502                      120                         OK
# 40503                      120                         OK
# 40504                      120                         OK
# 40505                      120                         OK
#
#        Collect Result.3 - AutoClave  Unit Time.3 - AutoClave  \
# 0                                50                      510
# 1                                50                      510
# 2                                54                      510
# 3                                49                      510
# 4                                50                      510
# ...                             ...                      ...
# 40501                            55                      361
# 40502                            55                      361
# 40503                            55                      361
# 40504                            55                      361
# 40505                            55                      361
#
#        Judge Value.3 - AutoClave  Collect Result.4 - AutoClave  \
# 0                             OK                           NaN
# 1                             OK                           NaN
# 2                             OK                           NaN
# 3                             NG                           NaN
# 4                             OK                           NaN
# ...                          ...                           ...
# 40501                         OK                           NaN
# 40502                         OK                           NaN
# 40503                         OK                           NaN
# 40504                         OK                           NaN
# 40505                         OK                           NaN
#
#        Judge Value.4 - AutoClave    target
# 0                            NaN  AbNormal
# 1                            NaN  AbNormal
# 2                            NaN  AbNormal
# 3                            NaN  AbNormal
# 4                            NaN  AbNormal
# ...                          ...       ...
# 40501                        NaN    Normal
# 40502                        NaN    Normal
# 40503                        NaN    Normal
# 40504                        NaN    Normal
# 40505                        NaN    Normal
#
# [40506 rows x 198 columns]

# %%
df_merged.to_csv('merge.csv', index=False)

# %%
df = pd.read_csv('merge.csv', low_memory=False)
df
# Out:
#       Wip Line - Dam Process Desc. - Dam   Equipment - Dam Model.Suffix - Dam  \
# 0            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 1            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 2            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 3            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# 4            IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334501
# ...              ...                 ...               ...                ...
# 40501        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40502        IVI-OB6       Dam Dispenser  Dam dispenser #2        AJX75334505
# 40503        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40504        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
# 40505        IVI-OB6       Dam Dispenser  Dam dispenser #1        AJX75334505
#
#       Workorder - Dam          LOT ID - Dam                Set ID  \
# 0          3F1X5847-2  OP753345013050000003  OP753345013050000003
# 1          3F1X5847-2  OP753345013050000004  OP753345013050000004
# 2          3F1X5847-2  OP753345013050000007  OP753345013050000007
# 3          3F1X5847-2  OP753345013050000011  OP753345013050000011
# 4          3F1X5847-2  OP753345013050000024  OP753345013050000024
# ...               ...                   ...                   ...
# 40501      4F1XB738-1  OP753345054040002680  OP753345054040002680
# 40502      4F1XB738-1  OP753345054040002681  OP753345054040002681
# 40503      4F1XB738-1  OP753345054040002682  OP753345054040002682
# 40504      4F1XB738-1  OP753345054040002684  OP753345054040002684
# 40505      4F1XB738-1  OP753345054040002688  OP753345054040002688
#
#       Collect Date - Dam  Insp. Seq No. - Dam Insp Judge Code - Dam  ...  \
# 0        2023-05-04 9:11                    1                    OK  ...
# 1        2023-05-04 9:13                    1                    OK  ...
# 2        2023-05-04 9:19                    1                    OK  ...
# 3       2023-05-04 11:19                    1                    OK  ...
# 4        2023-05-05 9:35                    1                    OK  ...
# ...                  ...                  ...                   ...  ...
# 40501   2024-04-28 18:25                    1                    OK  ...
# 40502   2024-04-28 18:26                    1                    OK  ...
# 40503   2024-04-28 18:27                    1                    OK  ...
# 40504   2024-04-28 18:29                    1                    OK  ...
# 40505   2024-04-28 18:33                    1                    OK  ...
#
#        Judge Value.1 - AutoClave  Collect Result.2 - AutoClave  \
# 0                             OK                         0.501
# 1                             OK                         0.501
# 2                             OK                         0.502
# 3                             OK                         0.500
# 4                             OK                         0.501
# ...                          ...                           ...
# 40501                         OK                         0.499
# 40502                         OK                         0.499
# 40503                         OK                         0.499
# 40504                         OK                         0.499
# 40505                         OK                         0.499
#
#        Unit Time.2 - AutoClave  Judge Value.2 - AutoClave  \
# 0                           90                         OK
# 1                           90                         OK
# 2                           90                         OK
# 3                           90                         OK
# 4                           90                         OK
# ...                        ...                        ...
# 40501                      120                         OK
# 40502                      120                         OK
# 40503                      120                         OK
# 40504                      120                         OK
# 40505                      120                         OK
#
#        Collect Result.3 - AutoClave  Unit Time.3 - AutoClave  \
# 0                                50                      510
# 1                                50                      510
# 2                                54                      510
# 3                                49                      510
# 4                                50                      510
# ...                             ...                      ...
# 40501                            55                      361
# 40502                            55                      361
# 40503                            55                      361
# 40504                            55                      361
# 40505                            55                      361
#
#        Judge Value.3 - AutoClave  Collect Result.4 - AutoClave  \
# 0                             OK                           NaN
# 1                             OK                           NaN
# 2                             OK                           NaN
# 3                             NG                           NaN
# 4                             OK                           NaN
# ...                          ...                           ...
# 40501                         OK                           NaN
# 40502                         OK                           NaN
# 40503                         OK                           NaN
# 40504                         OK                           NaN
# 40505                         OK                           NaN
#
#        Judge Value.4 - AutoClave    target
# 0                            NaN  AbNormal
# 1                            NaN  AbNormal
# 2                            NaN  AbNormal
# 3                            NaN  AbNormal
# 4                            NaN  AbNormal
# ...                          ...       ...
# 40501                        NaN    Normal
# 40502                        NaN    Normal
# 40503                        NaN    Normal
# 40504                        NaN    Normal
# 40505                        NaN    Normal
#
# [40506 rows x 198 columns]

# %%
df[['Wip Line - Dam', 'Wip Line - Fill1', 'Wip Line - Fill2', 'Wip Line - AutoClave']]
# Out:
#       Wip Line - Dam Wip Line - Fill1 Wip Line - Fill2 Wip Line - AutoClave
# 0            IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 1            IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 2            IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 3            IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 4            IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# ...              ...              ...              ...                  ...
# 40501        IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 40502        IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 40503        IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 40504        IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
# 40505        IVI-OB6          IVI-OB6          IVI-OB6              IVI-OB6
#
# [40506 rows x 4 columns]

# %%
df[['Process Desc. - Dam', 'Process Desc. - Fill1', 'Process Desc. - Fill2', 'Process Desc. - AutoClave']]
# Out:
#       Process Desc. - Dam Process Desc. - Fill1 Process Desc. - Fill2  \
# 0           Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 1           Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 2           Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 3           Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 4           Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# ...                   ...                   ...                   ...
# 40501       Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 40502       Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 40503       Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 40504       Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
# 40505       Dam Dispenser       Fill1 Dispenser       Fill2 Dispenser
#
#       Process Desc. - AutoClave
# 0                Auto Clave Out
# 1                Auto Clave Out
# 2                Auto Clave Out
# 3                Auto Clave Out
# 4                Auto Clave Out
# ...                         ...
# 40501            Auto Clave Out
# 40502            Auto Clave Out
# 40503            Auto Clave Out
# 40504            Auto Clave Out
# 40505            Auto Clave Out
#
# [40506 rows x 4 columns]

# %%
df[['Unnamed: 221 - Dam','Unnamed: 101 - Fill1','Unnamed: 131 - Fill2']]
# Out:
#        Unnamed: 221 - Dam  Unnamed: 101 - Fill1  Unnamed: 131 - Fill2
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# ...                   ...                   ...                   ...
# 40501                 7.0                   7.0                   0.0
# 40502                 7.0                   7.0                   0.0
# 40503                 7.0                   7.0                   0.0
# 40504                 7.0                   7.0                   0.0
# 40505                 7.0                   7.0                   0.0
#
# [40506 rows x 3 columns]
