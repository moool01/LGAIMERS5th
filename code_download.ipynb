# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# ### 데이터 읽어오기

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

# Load data
train_data = pd.read_csv(os.path.join(ROOT_DIR, "train_data_fix.csv"))
train_data
# Out:
#           Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0      Dam dispenser #1      AJX75334505    4F1XA938-1
# 1      Dam dispenser #1      AJX75334505    3KPM0016-2
# 2      Dam dispenser #2      AJX75334501    4E1X9167-1
# 3      Dam dispenser #2      AJX75334501    3K1X0057-1
# 4      Dam dispenser #1      AJX75334501    3HPM0007-1
# ...                 ...              ...           ...
# 40501  Dam dispenser #1      AJX75334501    3J1XF434-2
# 40502  Dam dispenser #2      AJX75334501    4E1XC796-1
# 40503  Dam dispenser #1      AJX75334501    4C1XD438-1
# 40504  Dam dispenser #2      AJX75334501    3I1XA258-1
# 40505  Dam dispenser #1      AJX75334501    3G1XA501-1
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...

# %%
# 결측치가 있는 열을 저장할 리스트
columns_with_na = train_data.columns[train_data.isna().any()].tolist()

# 결측치가 있는 열 삭제
train_data.dropna(axis=1, inplace=True)

# %% [markdown]
# ### 언더 샘플링

# %% [markdown]
# 데이타 불균형을 해결하기 위해 언더 샘플링을 진행합니다.

# %%
normal_ratio = 1.0  # 1.0 means 1:1 ratio

df_normal = train_data[train_data["target"] == "Normal"]
df_abnormal = train_data[train_data["target"] == "AbNormal"]

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)
print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}")

df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)
df_concat.value_counts("target")
# Out:
#   Total: Normal: 38156, AbNormal: 2350
# target
# AbNormal    2350
# Normal      2350
# Name: count, dtype: int64

# %% [markdown]
# ### 데이터 분할

# %%
df_train, df_val = train_test_split(
    df_concat,
    test_size=0.3,
    stratify=df_concat["target"],
    random_state=RANDOM_STATE,
)


def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)
# Out:
#   	Abnormal	Normal
#   Total: Normal: 1645, AbNormal: 1645 ratio: 1.0
#   Total: Normal: 705, AbNormal: 705 ratio: 1.0

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
features = []

for col in df_train.columns:
    try:
        df_train[col] = df_train[col].astype(int)
        features.append(col)
    except:
        continue

train_x = df_train[features]
train_y = df_train["target"]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150, 200,250,300],
    'max_depth': [None, 5, 10, 15, 20, 25, 30, 50],
    'min_samples_split': [2, 5, 10,20],
    'min_samples_leaf': [1, 2, 4,8,16]
}

model = RandomForestClassifier(random_state=RANDOM_STATE)
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           scoring='f1_weighted', cv=3, verbose=2, n_jobs=-1)
grid_search.fit(train_x, train_y)

best_model = grid_search.best_estimator_
print("Best parameters found: ", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 960 candidates, totalling 2880 fits
# e:\anaconda3\envs\sandbox\lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters found:  {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 150}

# %%
best_params = {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 20, 'n_estimators': 150, 'random_state': RANDOM_STATE}

model = RandomForestClassifier(**best_params)

# %%
train_x = pd.DataFrame(train_x).fillna(pd.DataFrame(train_x).mean())
train_x
# Out:
#       CURE END POSITION X Collect Result_Dam  \
# 4417                                     240
# 1383                                     240
# 895                                      240
# 1270                                    1000
# 1002                                    1000
# ...                                      ...
# 3021                                     240
# 2973                                     240
# 4040                                    1000
# 2294                                    1000
# 2789                                     240
#
#       CURE END POSITION Z Collect Result_Dam  \
# 4417                                       2
# 1383                                       2
# 895                                        2
# 1270                                      12
# 1002                                      12
# ...                                      ...
# 3021                                       2
# 2973                                       2
# ...

# %% [markdown]
# ### 모델 학습

# %%
model.fit(train_x, train_y)
# Out:
# RandomForestClassifier(random_state=110)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %% [markdown]
# 테스트 데이터 불러오기

# %%
test_data = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

# %%
df_test_x = test_data[features]

for col in df_test_x.columns:
    try:
        df_test_x.loc[:, col] = df_test_x[col].astype(int)
    except:
        continue

# %%
test_pred = model.predict(df_test_x)
test_pred
# Out:
# array(['AbNormal', 'Normal', 'AbNormal', ..., 'Normal', 'Normal',
#        'Normal'], dtype=object)

# %%
# 학습에 사용한 features 리스트를 그대로 사용
df_test_x = test_data[features]

# 각 열을 정수형으로 변환 시도
for col in df_test_x.columns:
    try:
        df_test_x.loc[:, col] = df_test_x[col].astype(int)
    except:
        continue

# 예측 수행
test_pred = model.predict(df_test_x)

# 예측 결과 출력
print(test_pred)
# Out:
# ['AbNormal' 'Normal' 'AbNormal' ... 'Normal' 'Normal' 'Normal']

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
